# %%
import pandas as pd
import numpy as np
import matplotlib. pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('AcademicPerformance.csv')

# %%
data
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
data.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04       NaN    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3    NaN          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0              16.0                2.0
# 1        F   Father         20.0              20.0                3.0
# 2      NaN   Father         10.0               7.0                0.0
# 3        F   Father         30.0              25.0                5.0
# 4        F   Father         40.0              50.0               12.0
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
data.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father          5.0               4.0
# 476    Geology        F   Father         50.0              77.0
# 477    Geology        S   Father         55.0              74.0
# 478    History        F   Father         30.0              17.0
# 479    History        S   Father         35.0              14.0
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                5.0           8                    No
# ...

# %%
data.notnull().sum()
# Out:
# gender                      470
# NationalITy                 480
# PlaceofBirth                480
# StageID                     480
# GradeID                     480
# SectionID                   474
# Topic                       480
# Semester                    471
# Relation                    480
# raisedhands                 470
# VisITedResources            475
# AnnouncementsView           476
# Discussion                  480
# ParentAnsweringSurvey       480
# ParentschoolSatisfaction    480
# StudentAbsenceDays          480
# Class                       480
# dtype: int64

# %%
data.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   470.000000        475.000000         476.000000  480.000000
# mean     47.506383         55.374737          38.237395   43.283333
# std      30.483226         32.769213          26.493621   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   20.000000
# 50%      50.000000         66.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    470 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 474 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  471 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               470 non-null    float64
#  10  VisITedResources          475 non-null    float64
#  11  AnnouncementsView         476 non-null    float64
#  12  Discussion                480 non-null    int64
# ...

# %%
data.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
sns.boxplot(y=data['raisedhands'])
# Out:
# <AxesSubplot:ylabel='raisedhands'>

# %%
sns.histplot(x = data ['raisedhands'])
# Out:
# <AxesSubplot:xlabel='raisedhands', ylabel='Count'>

# %%
data.dtypes
# Out:
# gender                       object
# NationalITy                  object
# PlaceofBirth                 object
# StageID                      object
# GradeID                      object
# SectionID                    object
# Topic                        object
# Semester                     object
# Relation                     object
# raisedhands                 float64
# VisITedResources            float64
# AnnouncementsView           float64
# Discussion                    int64
# ParentAnsweringSurvey        object
# ParentschoolSatisfaction     object
# StudentAbsenceDays           object
# Class                        object
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=480, step=1)

# %%
data.values
# Out:
# array([['M', 'KW', 'KuwaIT', ..., 'Good', 'Under-7', 'M'],
#        ['M', 'KW', 'KuwaIT', ..., 'Good', 'Under-7', 'M'],
#        ['M', 'KW', 'KuwaIT', ..., 'Bad', 'Above-7', 'L'],
#        ...,
#        ['F', 'Jordan', 'Jordan', ..., 'Bad', 'Under-7', 'M'],
#        ['F', 'Jordan', 'Jordan', ..., 'Bad', 'Above-7', 'L'],
#        ['F', 'Jordan', 'Jordan', ..., 'Bad', 'Above-7', 'L']],
#       dtype=object)

# %%
data.sort_values(by = ['GradeID'])
# Out:
#     gender NationalITy PlaceofBirth     StageID GradeID SectionID    Topic  \
# 129      M          KW       KuwaIT  lowerlevel    G-02         B       IT
# 118      F          KW       KuwaIT  lowerlevel    G-02         C       IT
# 119      M          KW       KuwaIT  lowerlevel    G-02         C       IT
# 120      M          KW       KuwaIT  lowerlevel    G-02         C       IT
# 121      M          KW       KuwaIT  lowerlevel    G-02         C       IT
# ..     ...         ...          ...         ...     ...       ...      ...
# 68       F         USA          USA  HighSchool    G-12         A       IT
# 49       F          KW       KuwaIT  HighSchool    G-12         A  English
# 48     NaN          KW       KuwaIT  HighSchool    G-12         A  English
# 47       F          KW       KuwaIT  HighSchool    G-12         A  English
# 66       F          KW       KuwaIT  HighSchool    G-12         A  English
#
# ...

# %%
data [10:15]
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 11      M          KW       KuwaIT  MiddleSchool    G-07         B  Math
# 12    NaN          KW       KuwaIT    lowerlevel    G-04       NaN     0
# 13      M     lebanon      lebanon  MiddleSchool    G-08         A  Math
# 14      F          KW       KuwaIT  MiddleSchool    G-08         A  Math
#
#    Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 10        F   Father         50.0              88.0               30.0
# 11        F   Father         19.0               6.0               19.0
# 12        F   Father          5.0               1.0                NaN
# 13      NaN   Father         20.0              14.0               12.0
# 14        F      Mum          NaN              70.0               44.0
#
#     Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
data ['GradeID']
# Out:
# 0      G-04
# 1      G-04
# 2      G-04
# 3      G-04
# 4      G-04
#        ...
# 475    G-08
# 476    G-08
# 477    G-08
# 478    G-08
# 479    G-08
# Name: GradeID, Length: 480, dtype: object

# %%
data.iloc[10:20,[1,2,3,4,5]]
# Out:
#    NationalITy PlaceofBirth       StageID GradeID SectionID
# 10          KW       KuwaIT  MiddleSchool    G-07         A
# 11          KW       KuwaIT  MiddleSchool    G-07         B
# 12          KW       KuwaIT    lowerlevel    G-04       NaN
# 13     lebanon      lebanon  MiddleSchool    G-08         A
# 14          KW       KuwaIT  MiddleSchool    G-08         A
# 15          KW       KuwaIT  MiddleSchool    G-06         A
# 16          KW       KuwaIT  MiddleSchool    G-07         B
# 17          KW       KuwaIT  MiddleSchool    G-07         A
# 18          KW       KuwaIT  MiddleSchool    G-07       NaN
# 19          KW       KuwaIT  MiddleSchool    G-07         B

# %%
data [data.raisedhands>90]
# Out:
#     gender  NationalITy PlaceofBirth       StageID GradeID SectionID    Topic  \
# 95       F           KW       KuwaIT    lowerlevel    G-02         B       IT
# 138      F       Jordan        Egypt  MiddleSchool    G-07         A    Quran
# 139      M       Jordan          USA  MiddleSchool    G-07         A    Quran
# 146      F      lebanon      lebanon  MiddleSchool    G-07         A    Quran
# 149      F       Jordan      lebanon  MiddleSchool    G-07         A    Quran
# 152      F  SaudiArabia          USA    HighSchool    G-11         B  Science
# 192      M           KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 196      M           KW       KuwaIT  MiddleSchool    G-08         A   Arabic
# 218      M           KW       KuwaIT  MiddleSchool    G-08         C  Spanish
# 239      M        Egypt        Egypt  MiddleSchool    G-07         B  Science
# 271      F       Jordan       Jordan  MiddleSchool    G-06         A  English
# ...

# %%
from numpy import nan
from pandas import read_csv
dataset = read_csv('AcademicPerformance.csv', header = None)
dataset[[1,2,3,4,5]] = dataset[[1,2,3,4,5]].replace(0, nan)
print (dataset.head(20))
# Out:
#         0            1             2             3        4          5   \
# 0   gender  NationalITy  PlaceofBirth       StageID  GradeID  SectionID
# 1        M           KW        KuwaIT    lowerlevel     G-04          A
# 2        M           KW        KuwaIT    lowerlevel     G-04        NaN
# 3        M           KW        KuwaIT    lowerlevel     G-04          A
# 4      NaN           KW        KuwaIT    lowerlevel     G-04          A
# 5        M           KW        KuwaIT    lowerlevel     G-04          A
# 6      NaN           KW        KuwaIT    lowerlevel     G-04          A
# 7        M           KW        KuwaIT  MiddleSchool     G-07        NaN
# 8        M           KW        KuwaIT  MiddleSchool     G-07          A
# 9        F           KW        KuwaIT  MiddleSchool     G-07          A
# 10     NaN           KW        KuwaIT  MiddleSchool     G-07          B
# 11       M           KW        KuwaIT  MiddleSchool     G-07          A
# ...

# %%
data.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                  0
# VisITedResources             5
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
data['raisedhands']= data['raisedhands'].fillna(method = 'ffill')
data.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                  0
# VisITedResources             5
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
data['raisedhands'][:20]
# Out:
# 0     15.0
# 1     20.0
# 2     10.0
# 3     30.0
# 4     40.0
# 5     42.0
# 6     35.0
# 7     50.0
# 8     12.0
# 9     70.0
# 10    50.0
# 11    19.0
# 12     5.0
# 13    20.0
# 14    20.0
# 15    30.0
# 16    36.0
# 17    55.0
# 18    69.0
# 19    70.0
# Name: raisedhands, dtype: float64
